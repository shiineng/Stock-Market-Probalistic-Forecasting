# %%
from probfunc import lnFit

# To access from another folder
import sys
import os
sys.path.append(os.path.abspath("../Data Cleaning"))
from Plotting import lnPlot, plotLineFit

# lnPlot('..//Data/Log_Simple_Returns.csv', 'Log-Data')

plotLineFit('..//Data/Log_Simple_Returns.csv', 'Simple Returns')

# %%
from Probability.probfunc import modelQuality
modelQuality('..//Data/Log_Simple_Returns.csv', 'Log-Data')
# Out:
#     Distribution           AIC           BIC  \
# 3      johnsonsu   5832.554561   5855.871491
# 4  genhyperbolic  11095.446846  11124.593009
# 0           norm  14787.671631  14799.330096
# 1              t  14789.671631  14807.159329
# 5      hypsecant  15438.683259  15450.341724
# 2        laplace  16093.717186  16105.375651
#
#                                               Params
# 3  (-5.847853450009545, 1221.5754722809506, 0, 94...
# 4  (1.7514994398963126, 0.5776935582656911, 0.577...
# 0                             (0, 4.583671483753172)
# 1          (42915147131314.08, 0, 4.583671366389826)
# 5                            (0, 3.7680414793226986)
# 2                            (0, 4.5183618871537705)

# %%
from probfunc import stockDNA, predictEnd2026, predictByDay2026

# a, b, loc, scale = stockDNA('../Data/Log_Simple_Returns.csv', 'Simple Returns')
# predictEnd2026(260.88, a, b, loc, scale)

# a, b, loc, scale = stockDNA('../Data/Spy_simple_returns.csv', 'Simple Returns')
# predictEnd2026(676.33, a, b, loc, scale)

a, b, loc, scale = stockDNA('../Data/Log_Simple_Returns.csv', 'Simple Returns')
predictByDay2026(260.81, a, b, loc, scale, 289)
# Out:
# 95% Daily VaR: -2.66%
# Proportion of positive or neutral return: 0.538
# Proportion of negative return: 0.462
# array([209.04671884, 323.98232044, 334.54709846, ..., 357.62840046,
#        576.78134822, 279.97817799], shape=(10000,))

# %%
from Probability.probfunc import getStockData
getStockData("SPY", '..//Data/Spy_simple_returns.csv')

# %%
from Probability.probfunc import compareToSPY
compareToSPY('..//Data/Log_Simple_Returns.csv', '..//Data/Spy_simple_returns.csv', 'Apple', 'SPY')
# Out:
# 95% Daily VaR: -2.66%
# 95% Daily VaR: -1.58%
#        Distribution  Skew_Shape(a)  Tail_Shape(b)  Location(μ)  Scale(σ)  \
# Ticker
# Apple    Johnson SU         0.0249         1.1510       0.1554    1.3954
# SPY      Johnson SU         0.0811         1.0368       0.1505    0.6801
#
#         Annual Volatility  Annual Return  Sharpe Ratio
# Ticker
# Apple              22.151        39.1637        1.7658
# SPY                10.797        37.9333        3.5087
