# %%
from market_test import overall_analysis

overall_analysis("NVDA", "2005-08-22", "2026-03-12", "Close", 183.16, 287, 10000, 'blue', 'pink')
overall_analysis("SPY", "2005-08-22", "2026-03-12", "Close", 666.06, 287, 10000, 'red', 'purple')
# Out:
# AIC TEST:
#    Distribution:           AIC           BIC  \
# 3      johnsonsu  25366.780249  25392.981987
# 4  genhyperbolic  25373.136182  25405.888355
# 1              t  25392.382674  25412.033977
# 2        laplace  25428.127171  25441.228040
# 5      hypsecant  25447.267221  25460.368090
# 6       skewnorm  26288.279311  26307.930615
# 0           norm  26303.532869  26316.633738
# 7         cauchy  26305.656849  26318.757718
#
#                                               Params  Param Quantity
# 3  (-0.06170316041127561, 1.2672688697998535, 0, ...               4
# 4  (-0.9827259028714297, 0.617498530782929, 0.058...               5
# 1         (3.519762375628428, 0, 2.0886353556971837)               3
# 2                            (0, 2.1514490169863643)               2
# 5                            (0, 1.8456861302479948)               2
# 6       (0.07271608456106832, 0, 3.0802813105464084)               3
# ...
