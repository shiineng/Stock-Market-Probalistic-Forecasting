# %%
from market_test import overall_analysis

overall_analysis("NVDA", "2017-01-01", "2026-03-12", "Close", 183.14, 294, 10000, 'blue', 'pink')
# Out:
# AIC TEST:
#    Distribution:           AIC           BIC  \
# 3      johnsonsu  11542.945342  11565.921889
# 4  genhyperbolic  11547.710702  11576.431385
# 1              t  11556.878799  11574.111209
# 5      hypsecant  11567.644273  11579.132547
# 2        laplace  11590.542180  11602.030453
# 6       skewnorm  11844.435292  11861.667702
# 0           norm  11855.433574  11866.921847
# 7         cauchy  12030.400239  12041.888513
#
#                                               Params  Param Quantity
# 3  (-0.08243771265234573, 1.420877836979774, 0, 3...               4
# 4  (-1.949488597024316, 0.42805591231844237, 0.11...               5
# 1         (4.229402579042171, 0, 2.3056858069762063)               3
# 5                            (0, 1.9403992745128198)               2
# 2                            (0, 2.2635527991673943)               2
# 6       (0.09460645599700118, 0, 3.1535450994834635)               3
# ...
