# %%
from market_test import overall_analysis

overall_analysis("SPY", "2005-08-22", "2026-03-12", "Close", 600, 365, 10000)
# Out:
# AIC TEST:
#    Distribution:           AIC           BIC  \
# 3      johnsonsu  14739.095239  14765.296977
# 4  genhyperbolic  14762.544311  14795.296483
# 1              t  14785.150060  14804.801364
# 2        laplace  14860.593670  14873.694539
# 5      hypsecant  15069.140413  15082.241282
# 7         cauchy  15385.279519  15398.380388
# 6       skewnorm  16644.468288  16664.119591
# 0           norm  16650.516604  16663.617473
#
#                                               Params  Param Quantity
# 3  (-0.07118005980180159, 0.9991871447625018, 0, ...               4
# 4  (-0.5786787608767279, 0.3251748873406891, 0.02...               5
# 1        (2.4908879108228277, 0, 0.6571721209998886)               3
# 2                            (0, 0.7740945031249513)               2
# 5                             (0, 0.665973368927425)               2
# 7                           (0, 0.47148468420576867)               2
# ...
